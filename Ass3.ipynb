# %%
ans = None
num1 = int(input("Enter first value: "))
num2 = int(input("Enter second value: "))

print("\nEnter 1 to do addition :")
print("Enter 2 to do subtraction :")
print("Enter 3 to do multiplication :")
print("Enter 4 to do division :")
print("Enter 5 to do power: ")
choice = int(input("Enter your choice: "))

if choice == 1:
    ans = num1+num2
elif choice == 2:
    ans = num1-num2
elif choice == 3:
    ans = num1*num2
elif choice == 4:
    ans = num1/num2
elif choice == 5:
    ans = num1**num2
    
print(f"\nAnswer : {ans}")
# Out:
# Enter first value: 3
# Enter second value: 2
#
# Enter 1 to do addition :
# Enter 2 to do subtraction :
# Enter 3 to do multiplication :
# Enter 4 to do division :
# Enter 5 to do power:
# Enter your choice: 1
#
# Answer : 5

# %%
the_list = ["Ayan",  "3", 4,"Hello"]
for value in the_list:
    if type(value) == int or type(value) == float:
        print(f"Numeric value found : {value}")
        break
# Out:
# Numeric value found : 4

# %%
dic = {}
dic[1] = "Key added"

print(dic[1])
# Out:
# Key added

# %%
result = 0
dic = {1: 2 ,
           2: "Ayan", 
           3: 4.4, 
           4:"Not numerical",
           5: 100}

for value in dic.values():
    if type(value) == int or type(value) == float:
        result = result + value        
        
print(f"Sum = {result}")
# Out:
# Sum = 106.4

# %%
the_list = ["Ayan", "Ayan", 1, 1, 0.4, 0.4, 2, 3, 4, 5, 6]
for value in the_list:
    if  the_list.count(value) > 1:
        print(f"Duplicated {value}")
# Out:
# Duplicated Ayan
# Duplicated Ayan
# Duplicated 1
# Duplicated 1
# Duplicated 0.4
# Duplicated 0.4

# %%
dic = { 1: "key1",
            2: "key2",
            3: "key3"}

given_key = 3

for key in dic.keys():
    if key == given_key:
        print(f"{given_key} Already exists")
# Out:
# 3 Already exists
